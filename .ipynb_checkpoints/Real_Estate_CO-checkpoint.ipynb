# %%
import requests

url = "https://realty-in-us.p.rapidapi.com/locations/auto-complete"

querystring = {"input":"Colorado"}

headers = {
    'x-rapidapi-host': "realty-in-us.p.rapidapi.com",
    'x-rapidapi-key': "94a42240cfmsh6bdc51bd3316b69p1f7068jsndbdae3708e94"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"meta":{"build":"3.23.180"},"autocomplete":[{"area_type":"city","_id":"city:co_colorado-springs","_score":13.558095,"city":"Colorado Springs","state_code":"CO","counties":[{"name":"El Paso","fips":"08041","state_code":"CO"}],"country":"USA","centroid":{"lon":-104.760749,"lat":38.8672553},"slug_id":"Colorado-Springs_CO","geo_id":"07176159-9459-52b4-8ee7-ec3f9a7d8f19","county_needed_for_uniq":false},{"area_type":"city","_id":"city:co_colorado-city","_score":13.160895,"city":"Colorado City","state_code":"CO","counties":[{"name":"Pueblo","fips":"08101","state_code":"CO"}],"country":"USA","centroid":{"lon":-104.8456012,"lat":37.9366509},"slug_id":"Colorado-City_CO","geo_id":"9d673ffb-5e23-5f3d-be0e-ba2ed73a50aa","county_needed_for_uniq":false},{"area_type":"city","_id":"city:tx_colorado-city","_score":13.017378,"city":"Colorado City","state_code":"TX","counties":[{"name":"Mitchell","fips":"48335","state_code":"TX"}],"country":"USA","centroid":{"lon":-100.8583036,"lat":32.399486},"slug_id
# ...

# %%
#import pprint 
#pprint.pprint(response.text)

# %%
real_estate_df = pd.DataFrame(response.json())
real_estate_df.head(10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-6e7149f38d92> in <module>
# ----> 1 real_estate_df = pd.DataFrame(response.json())
#       2 real_estate_df.head(10)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
#     528         elif isinstance(data, dict):
# --> 529             mgr = init_dict(data, index, columns, dtype=dtype)
#     530         elif isinstance(data, ma.MaskedArray):
#     531             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     285             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     286         ]
# --> 287     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     288
#     289
#
# ...

# %%
real_estate_df = pd.DataFrame(response.json()['autocomplete'])
real_estate_df.head(10)
# Out:
#   area_type                       _id     _score              city state_code  \
# 0      city  city:co_colorado-springs  13.558095  Colorado Springs         CO
# 1      city     city:co_colorado-city  13.160895     Colorado City         CO
# 2      city     city:tx_colorado-city  13.017378     Colorado City         TX
# 3      city     city:az_colorado-city  12.936977     Colorado City         AZ
# 4    school         school:0711455401  12.869191  Colorado Springs         CO
# 5    school         school:0711455631  12.816391  Colorado Springs         CO
# 6    school         school:0711503441  12.798561         Englewood         CO
# 7    school         school:0711506561  12.747992  Colorado Springs         CO
# 8      city    city:tx_colorado-acres  12.719778    Colorado Acres         TX
# 9    school         school:0711465401  12.697754  Colorado Springs         CO
#
#                                             counties country  \
# ...
