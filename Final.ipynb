# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd

# Files to Load 
income1514_to_load = "Resources/income_1514.csv"
income_1_to_load = "Resources/income_1.csv"


# Read the Income Data
income1514_df = pd.read_csv(income1514_to_load)
income_1_df = pd.read_csv(income_1_to_load)

# %%
# Combine the data into a single dataset
merged_df = pd.merge(income1514_df, income_1_df, how="left", on=["GEO_ID", "GEO_ID"])

# Display the data table for preview
merged_df.head(5)
# Out:
#                  GEO_ID  Households!!Estimate!!Total_x  \
# 0  1400000US08031000102                           1584
# 1  1400000US08031000201                           1531
# 2  1400000US08031000202                           1676
# 3  1400000US08031000301                           2660
# 4  1400000US08031000302                           2026
#
#   Households!!Estimate!!Less than $10,000_x  \
# 0                                       5.6
# 1                                       7.8
# 2                                      17.1
# 3                                       7.6
# 4                                         0
#
#   Households!!Estimate!!$10,000 to $14,999_x  \
# 0                                        2.3
# 1                                        7.3
# 2                                        5.6
# 3                                        4.5
# 4                                        4.6
#
#   Households!!Estimate!!$15,000 to $24,999_x  \
# ...

# %%
# Export the CSV
merged_df.to_csv('income_final.csv', index = False)
