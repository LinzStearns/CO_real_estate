# %%
# Import dependencies 
import pandas as pd

# %%
# File to Load
file_to_load = "real_property_sales_and_transfers.csv"

# %%
# Read the CSV
real_property_sales_and_transfers_df = pd.read_csv(file_to_load)
real_property_sales_and_transfers_df.head()
# Out:
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3166: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         PARID RECEPTION_NUM INSTRUMENT  SALE_YEAR  SALE_MONTHDAY  \
# 0  3100014000    2017095534         WD       2017            720
# 1  3100015000    2017095534         WD       2017            720
# 2  3100016000    2017095534         WD       2017            720
# 3  3100025000    2015007009         WD       2015            120
# 4  3100028000    2011125634         WD       2011           1102
#
#    RECEPTION_DATE  SALE_PRICE                    GRANTOR  \
# 0      20170721.0    12500000     LNR CPI HIGH POINT LLC
# 1      20170721.0    12500000     LNR CPI HIGH POINT LLC
# 2      20170721.0    12500000     LNR CPI HIGH POINT LLC
# 3      20150121.0     9350000  PEP LENOCH DENVER V LLC &
# ...

# %%
real_property_sales_and_transfers_df.dropna()
# Out:
#                PARID RECEPTION_NUM INSTRUMENT  SALE_YEAR  SALE_MONTHDAY  \
# 116       3107001000    2017095534         WD       2017            720
# 117       3107001000    2020106308         CD       2020            512
# 130       3110004000    2020037887         WD       2020            313
# 131       3110004000    2020037888         WD       2020            313
# 136       3111001000    2020037887         WD       2020            313
# ...              ...           ...        ...        ...            ...
# 316426  915401170170    2016075175         WD       2016            607
# 316427  915401171171    2018061978         WD       2018            524
# 316428  915401172172    2020081138         TR       2020            612
# 316429  915401173173    2015050226         WD       2015            420
# 316430  915401173173    2015104940         WD       2015            727
#
#         RECEPTION_DATE  SALE_PRICE                     GRANTOR  \
# ...

# %%
Residential_sales_df = real_property_sales_and_transfers_df[(real_property_sales_and_transfers_df["D_CLASS_N"] == "RESIDENTIAL")]
Residential_sales_df
# Out:
#                PARID RECEPTION_NUM INSTRUMENT  SALE_YEAR  SALE_MONTHDAY  \
# 59247   131305017000    2015012663         QC       2015            128
# 59248   131305017000    2017091851         WD       2017            714
# 59249   131305017000    2019180761         WD       2019           1219
# 59250   131305017000    2020125794         WD       2020            810
# 59251   131305017000    2020174265         WD       2020           1015
# ...              ...           ...        ...        ...            ...
# 276966  618407032000    2015146570         QC       2015           1009
# 276967  618407032000    2020079082         QC       2020            429
# 276968  618407032000    2020117531         QC       2020            731
# 287600  630202027000    2020193181         PS       2020           1022
# 290339  631322027000    2021099325         PS       2021            525
#
#         RECEPTION_DATE  SALE_PRICE                               GRANTOR  \
# ...
