# %%
# Add Matplotlib inline magic command
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd

# Files to Load 
income2019_to_load = "Resources/ACSST5Y2019_income_data.csv"
income2018_to_load = "Resources/ACSST5Y2018_income_data.csv"


# Read the Income Data
income2019_df = pd.read_csv(income2019_to_load)
income2018_df = pd.read_csv(income2018_to_load)

# %%
# Combine the data into a single dataset
merged_df = pd.merge(income2019_df, income2018_df, how="left", on=["GEO_ID", "GEO_ID"])

# Display the data table for preview
merged_df.head(5)
# Out:
#                  GEO_ID                                      NAME_x  \
# 0                    id                        Geographic Area Name
# 1  1400000US08031000102  Census Tract 1.02, Denver County, Colorado
# 2  1400000US08031000201  Census Tract 2.01, Denver County, Colorado
# 3  1400000US08031000202  Census Tract 2.02, Denver County, Colorado
# 4  1400000US08031000301  Census Tract 3.01, Denver County, Colorado
#
#                      Estimate Occupied housing units  \
# 0  Estimate!!Occupied housing units!!Occupied hou...
# 1                                               1603
# 2                                               1663
# 3                                               1773
# 4                                               2808
#
#                                       S2503_C01_001M  \
# 0  Margin of Error!!Occupied housing units!!Occup...
# 1                                                 95
# 2                                                 91
# ...
