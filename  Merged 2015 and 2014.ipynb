# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd

# Files to Load 
income2015_to_load = "Resources/income_2015.csv"
income2014_to_load = "Resources/income_2014.csv"


# Read the Income Data
income2015_df = pd.read_csv(income2015_to_load)
income2014_df = pd.read_csv(income2014_to_load)

# %%
# Combine the data into a single dataset
merged_df = pd.merge(income2015_df, income2014_df, how="left", on=["GEO_ID", "GEO_ID"])

# Display the data table for preview
merged_df.head(5)
# Out:
#                  GEO_ID  Households!!Estimate!!Total_x  \
# 0  1400000US08031000102                           1584
# 1  1400000US08031000201                           1531
# 2  1400000US08031000202                           1676
# 3  1400000US08031000301                           2660
# 4  1400000US08031000302                           2026
#
#   Households!!Estimate!!Less than $10,000_x  \
# 0                                       5.6
# 1                                       7.8
# 2                                      17.1
# 3                                       7.6
# 4                                         0
#
#   Households!!Estimate!!$10,000 to $14,999_x  \
# 0                                        2.3
# 1                                        7.3
# 2                                        5.6
# 3                                        4.5
# 4                                        4.6
#
#   Households!!Estimate!!$15,000 to $24,999_x  \
# 0                                        8.6
# 1                                        9.9
# 2                                        8.8
# 3                                        6.8
# 4                                        3.7
#
#   Households!!Estimate!!$25,000 to $34,999_x  \
# 0                                        8.3
# 1                                        6.4
# 2                                        8.2
# 3                                       10.8
# 4                                          9
#
#   Households!!Estimate!!$35,000 to $49,999_x  \
# 0                                        6.3
# 1                                       21.6
# 2                                        8.1
# 3                                       13.2
# 4                                       16.7
#
#   Households!!Estimate!!$50,000 to $74,999_x  \
# 0                                       24.2
# 1                                       15.1
# 2                                       14.3
# 3                                       15.7
# 4                                       13.3
#
#   Households!!Estimate!!$75,000 to $99,999_x  \
# 0                                       11.7
# 1                                       14.5
# 2                                       16.3
# 3                                        7.3
# 4                                       12.7
#
#   Households!!Estimate!!$100,000 to $149,999_x  ...  \
# 0                                         19.3  ...
# 1                                         12.5  ...
# 2                                         15.1  ...
# 3                                         19.2  ...
# 4                                           20  ...
#
#   Households!!Estimate!!$25,000 to $34,999_y  \
# 0                                       11.2
# 1                                        5.6
# 2                                        6.9
# 3                                        8.6
# 4                                        9.3
#
#   Households!!Estimate!!$35,000 to $49,999_y  \
# 0                                        7.6
# 1                                       19.9
# 2                                        9.5
# 3                                       14.4
# 4                                       12.7
#
#   Households!!Estimate!!$50,000 to $74,999_y  \
# 0                                       19.9
# 1                                       16.7
# 2                                         13
# 3                                       18.3
# 4                                       13.2
#
#   Households!!Estimate!!$75,000 to $99,999_y  \
# 0                                       14.4
# 1                                       14.7
# 2                                       12.8
# 3                                        7.6
# 4                                         16
#
#   Households!!Estimate!!$100,000 to $149,999_y  \
# 0                                         20.1
# 1                                         13.7
# 2                                         16.8
# 3                                         20.7
# 4                                         21.3
#
#    Households!!Estimate!!$150,000 to $199,999_y  \
# 0                                             4
# 1                                           2.5
# 2                                           6.7
# 3                                           7.6
# 4                                          11.4
#
#   Households!!Estimate!!$200,000 or more_y  \
# 0                                      8.5
# 1                                      2.5
# 2                                      2.7
# 3                                      4.1
# 4                                      7.1
#
#   Households!!Estimate!!Median income (dollars)_y  \
# 0                                           70244
# 1                                           50750
# 2                                           53578
# 3                                           57269
# 4                                           84846
#
#   Households!!Estimate!!Mean income (dollars)_y  \
# 0                                         86999
# 1                                         63717
# 2                                         67391
# 3                                         79421
# 4                                        100154
#
#   Households!!Estimate!!PERCENT IMPUTED!!Household income in the past 12 months_y
# 0                                               22.8
# 1                                               26.9
# 2                                               25.8
# 3                                               22.6
# 4                                               18.3
#
# [5 rows x 29 columns]

# %%
# Export the CSV
merged_df.to_csv('income_1514.csv', index = False)
