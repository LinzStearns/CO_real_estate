# %%
# Add Matplotlib inline magic command
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd

# Files to Load 
income2015_to_load = "Resources/ACSST5Y2015_income_data.csv"
income2014_to_load = "Resources/ACSST5Y2014_income_data.csv"


# Read the Income Data
income2015_df = pd.read_csv(income2015_to_load)
income2014_df = pd.read_csv(income2014_to_load)

# %%
# Combine the data into a single dataset
merged_df = pd.merge(income2015_df, income2014_df, how="left", on=["GEO_ID", "GEO_ID"])

# Display the data table for preview
merged_df.head(5)
# Out:
#                  GEO_ID                                      NAME_x  \
# 0                    id                        Geographic Area Name
# 1  1400000US08031000102  Census Tract 1.02, Denver County, Colorado
# 2  1400000US08031000201  Census Tract 2.01, Denver County, Colorado
# 3  1400000US08031000202  Census Tract 2.02, Denver County, Colorado
# 4  1400000US08031000301  Census Tract 3.01, Denver County, Colorado
#
#               S1901_C01_001E_x                    S1901_C01_001M_x  \
# 0  Households!!Estimate!!Total  Households!!Margin of Error!!Total
# 1                         1584                                  71
# 2                         1531                                  67
# 3                         1676                                  73
# 4                         2660                                 112
#
#                           S1901_C01_002E_x  \
# 0  Households!!Estimate!!Less than $10,000
# 1                                      5.6
# ...

# %%
# Export the CSV
#merged_df.to_csv('income_1514.csv', index = False)
