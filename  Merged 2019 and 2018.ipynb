# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd

# Files to Load 
income2019_to_load = "Resources/income_2019.csv"
income2018_to_load = "Resources/income_2018.csv"


# Read the Income Data
income2019_df = pd.read_csv(income2019_to_load)
income2018_df = pd.read_csv(income2018_to_load)

# %%
# Combine the data into a single dataset
merged_df = pd.merge(income2019_df, income2018_df, how="left", on=["GEO_ID", "GEO_ID"])

# Display the data table for preview
merged_df.head(5)
# Out:
#                  GEO_ID  \
# 0  1400000US08031000102
# 1  1400000US08031000201
# 2  1400000US08031000202
# 3  1400000US08031000301
# 4  1400000US08031000302
#
#    Estimate!!Occupied housing units!!Occupied housing units!!HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS)!!Less than $5,000  \
# 0                                                 26
# 1                                                 20
# 2                                                104
# 3                                                206
# 4                                                 23
#
#    Estimate!!Occupied housing units!!Occupied housing units!!HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS)!!$5,000 to $9,999  \
# 0                                                 47
# 1                                                 32
# 2                                                145
# 3                                                 52
# ...

# %%
# Export the CSV
merged_df.to_csv('income_1819.csv', index = False)
