# %%
# Add Matplotlib inline magic command
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd

# Files to Load 
income2017_to_load = "Resources/ACSST5Y2017_income_data.csv"
income2016_to_load = "Resources/ACSST5Y2016_income_data.csv"


# Read the Income Data
income2017_df = pd.read_csv(income2017_to_load)
income2016_df = pd.read_csv(income2016_to_load)

# %%
# Combine the data into a single dataset
merged_df = pd.merge(income2017_df, income2016_df, how="left", on=["GEO_ID", "GEO_ID"])

# Display the data table for preview
merged_df.head(5)
# Out:
#                  GEO_ID                                      NAME_x  \
# 0                    id                        Geographic Area Name
# 1  1400000US08031000102  Census Tract 1.02, Denver County, Colorado
# 2  1400000US08031000201  Census Tract 2.01, Denver County, Colorado
# 3  1400000US08031000202  Census Tract 2.02, Denver County, Colorado
# 4  1400000US08031000301  Census Tract 3.01, Denver County, Colorado
#
#    Estimate!!Households!!Total                        S1901_C01_001M_x  \
# 0  Estimate!!Households!!Total  Margin of Error!!Households MOE!!Total
# 1                         1592                                      93
# 2                         1602                                      70
# 3                         1709                                      97
# 4                         2746                                     163
#
#                                  S1901_C01_002E_x  \
# 0  Estimate!!Households!!Total!!Less than $10,000
# ...

# %%
# Export the CSV
#merged_df.to_csv('income_1716.csv', index = False)
