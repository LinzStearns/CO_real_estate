# %%
# Import dependencies
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

# %%
# Load in CSV as a DataFrame
df = pd.read_csv('Resources/rentals.csv')
display(df)
# Out:
#      RegionID                          RegionName  SizeRank  2014-01  2014-02  \
# 0      102001                       United States         0   1294.0     1299
# 1      394913                        New York, NY         1   2256.0     2266
# 2      753899  Los Angeles-Long Beach-Anaheim, CA         2   1792.0     1803
# 3      394463                         Chicago, IL         3   1411.0     1415
# 4      394514               Dallas-Fort Worth, TX         4   1128.0     1132
# ..        ...                                 ...       ...      ...      ...
# 97     394957                       Melbourne, FL        97    945.0      950
# 98     395113                         Spokane, WA        99    946.0      942
# 99     395006                           Provo, UT       100    998.0     1002
# 100    394746                         Killeen, TX       128    867.0      868
# 101    394483                 College Station, TX       192   1194.0     1199
#
# ...

# %%
#df["RegionName"][-2:]

# %%
#for i in range(0,len(df["RegionName"])):
    #if(df["RegionName"][i][-2:])=="CO":
        #print(df["RegionName"][i])

# %%
# making data frame from csv file
data = pd.read_csv("Resources/rentals.csv", index_col ="RegionName")
  
# retrieving rows by loc method
rows = data.loc["Colorado Springs, CO"]
  
# checking data type of rows
print(type(rows))
  
# display
rows
# Out:
# <class 'pandas.core.series.Series'>
# RegionID    394484.0
# SizeRank        80.0
# 2014-01       1026.0
# 2014-02       1030.0
# 2014-03       1035.0
#               ...
# 2021-09       1693.0
# 2021-10       1712.0
# 2021-11       1730.0
# 2021-12       1749.0
# 2022-01       1768.0
# Name: Colorado Springs, CO, Length: 99, dtype: float64

# %%
COSprings_df = pd.DataFrame(rows)
COSprings_df.head(10)
# Out:
#           Colorado Springs, CO
# RegionID              394484.0
# SizeRank                  80.0
# 2014-01                 1026.0
# 2014-02                 1030.0
# 2014-03                 1035.0
# 2014-04                 1039.0
# 2014-05                 1044.0
# 2014-06                 1048.0
# 2014-07                 1052.0
# 2014-08                 1057.0

# %%
# Create the output file (CSV) & export file 
COSprings_df.to_csv(path_or_buf='COSprings.csv', index_label="Year-Mo")
